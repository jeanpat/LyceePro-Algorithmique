# %% [markdown]
# # Pour quelques supers pouvoirs de plus: des calculs numériques justes.
# Commençons par importer un module  pour manipuler les fractions en executant le code:
# ```python
# from fractions import Fraction
# ```
#
# On sélectionnera la cellule ci-dessous et on cliquera sur le bouton **Run** ou plus simplement on tapera sur le clavier **SHIFT+Entrée**

# %%
from fractions import Fraction

# %% [markdown]
# ## Fractions
#    * Ecrire et afficher des fractions
#    * approximation décimale d'une fraction
#    * Opération sur les fractions
#
# Commençons par écrire une fraction, par exemple: $\dfrac{20}{6}$, en tapant le code:
#
# ```python
# Fraction(20,6)
# ```

# %%
Fraction(20,6)

# %%
print(Fraction(20,6))

# %% [markdown]
# Avez-vous remarqué que la fraction $\dfrac{20}{6}$ a été réduite automatiquement en $\dfrac{10}{3}$?
#
# Ecrivons sa valeur approchée en tapant dans la cellule ci-dessous:
# ```python
#     float(Fraction(20,6))
#  ```

# %%
float(Fraction(20,6))

# %% [markdown]
# ### Somme de deux fractions:
# Dans la première cellule ci-dessous, additionner $\dfrac{5}{6} + \dfrac{7}{2}$

# %% [markdown]
# Puis dans la deuxième cellule ci-dessous, donner une valeur décimale approchée de ce nombre:

# %% [markdown]
# ### Produit et quotient de deux fractions
# Pour multiplier deux nombres en python on utilise *****:
#
# ``` python
#     2*3
# ```
# Vérifier que le résultat est bien **6**

# %% [markdown]
# Calculons la valeur exacte du produit $\dfrac{5}{6} \times \dfrac{7}{2}$:

# %% [markdown]
# Pour diviser deux nombres, en python, on utilise l'opérateur **/**, par exemple, tapons dans la cellule ci-dessous:
#
# ```python
#     12/4
# ```
# remarquons que si la tape:
#
# ```python
#     12//4
# ```
# on obtient le résulat de la division entière. Que doit-on obtenir, si l'on tape **14//4**?

# %% [markdown]
# Pour avoir le reste de la division entière de 14 par 4, on utilise l'opérateur **%**, exemple:
#
# ```python
# 14%4
# ```

# %% [markdown]
# ### Quotient de deux fractions:
# Calculons maintenant le quotient de deux fractions. Pour alléger les opérations, attachons une étiquette, une **variable**, à chaque fraction. On souhaite calculer le quotient suivant:
# $$\dfrac{\dfrac{10}{3}}{\dfrac{5}{2}}$$
# Pour alléger l'écriture, on pose donc:
# $p=\dfrac{10}{3}$ et $q= \dfrac{5}{2}$
# et on calcule:
#
# $$r=\dfrac{p}{q}$$
#
# Taper le code suivant dans la cellule ci-dessous:
#
# ```python
# p = Fraction(10,3)
# q = Fraction(5,2)
# r= p/q
# print(r)
# ```
#
# Vous devez vérifier que *diviser c'est multiplier par l'inverse*, on aura $\dfrac{10}{3} \times \dfrac{2}{5}= \dfrac{10 \times 2}{3 \times 5}=\dfrac{4}{3}$

# %% [markdown]
# ### Numérateur et dénominateur:
# Demandons le numérateur et le dénominateur d'une fraction $f=\frac{5}{2}$

# %%
f = Fraction(5,2)
print("le numérateur de ", f, " est:",f.numerator)
print("le dénominateur de ", f, " est:",f.denominator)

# %% [markdown]
# Afficher le numérateur et le dénominateur de $\dfrac{78}{12}$

# %% [markdown]
# # Exercices
# En prenant:
# $p=\dfrac{10}{3}$ et $q=\dfrac{5}{2}$
#
# Dans la cellule ci-dessous calculer et afficher les résulats des opérations suivantes:
#
# $p+q$  ;  $p-q$  ;  $q-p$   ;  $p \times q$   ;  $\dfrac{p}{q}$
#
# Puis dans la cellule suivante, calculer $$\dfrac{1}{\dfrac{p}{q}}$$
#
# et vérifier que c'est égal à $\dfrac{p}{q}$ à l'aide du code:
#
# ```python
# q/p == 1/(p/q)
# ```
# Le résultat doit être:
# ```python
# True
# ```
# Ce qui signifie que le calcul est **vrai** donc juste.

# %%
p = Fraction(10,3)
q =
print()
print()
print()
print()
print()

# %%
q/p == 1/(p/q)

# %% [markdown]
# ## Le module Fraction produit des calculs justes:
# Que se passerait-il si l'on faisait les mêmes calculs sans utiliser ce module?
# Recommençons cette fois ci en réalisant les calculs:
#
# ```python
# p = 10/3
# q = 5/2
# r= p/q
# print(r)
# print( q/p == 1/r)
# ```
# Taper ou copier/coller ce code dans la cellule ci-dessous:

# %%
p = 10/3
q = 5/2
r= p/q
print("la valeur numérique approchée de 10/3 est:",p)
print("la valeur numérique approchée de 5/2 est:",q)
print("la valeur numérique approchée de p/q est:",r)
print("la valeur numérique approchée de q/p est:",q/p)
print("   Cette valeur devrait être identique à 1/r:",1/r)
print("q/p devrait être égal à 1/r:",q/p == 1/r)
